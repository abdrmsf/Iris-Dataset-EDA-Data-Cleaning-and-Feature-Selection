# %% [markdown]
# ## Iris Dataset ---> This is the Dataset for Flowers

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('iris.csv')
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
## Top 5 records of Dataset
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
## Bottom 5 records of Dataset
df.tail()
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica

# %%
## Shape of the Dataset
df.shape
# Out:
# (150, 6)

# %%
## Data types
df.dtypes
# Out:
# Id                 int64
# SepalLengthCm    float64
# SepalWidthCm     float64
# PetalLengthCm    float64
# PetalWidthCm     float64
# Species           object
# dtype: object

# %%
## Statistical Summary
df.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
## Missing Values
df.isnull().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
## Checking for Duplicates
df.duplicated().sum()
# Out:
# 0

# %%
## Checking for Outliers
plt.figure(figsize=(10,8))
numerical_columns=['SepalLengthCm','SepalWidthCm','PetalLengthCm','PetalWidthCm']
value=1
for cols in numerical_columns:
    plt.subplot(2,2,value)
    sns.boxplot(x=df[cols])
    value+=1

plt.tight_layout()

# %%
df[(df['SepalWidthCm']>4) | (df['SepalWidthCm']==2)]
# Out:
#     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 15  16            5.7           4.4            1.5           0.4
# 32  33            5.2           4.1            1.5           0.1
# 33  34            5.5           4.2            1.4           0.2
# 60  61            5.0           2.0            3.5           1.0
#
#             Species
# 15      Iris-setosa
# 32      Iris-setosa
# 33      Iris-setosa
# 60  Iris-versicolor

# %% [markdown]
# ## EDA

# %%
plt.figure(figsize=(10,8))
numerical_columns=['SepalLengthCm','SepalWidthCm','PetalLengthCm','PetalWidthCm']
value=1
for cols in numerical_columns:
    plt.subplot(2,2,value)
    sns.histplot(x=df[cols],kde=True)
    value+=1

plt.tight_layout()

# %% [markdown]
# ## From the above graph we can see that most flowers have average sepallength and sepalwidth(due to being normally distributed)

# %% [markdown]
# ## But we can notice a gap in PetalLengthCm and PetalWidthCm ---> the left to the gap is Iris setosa and the right to the gap is Iris-Versicolor and Iris-Virginica as observed in the dataset ---> so these two columns are very important for the dataset

# %%
plt.figure(figsize=(10,8))
numerical_columns=['SepalLengthCm','SepalWidthCm','PetalLengthCm','PetalWidthCm']
value=1
for cols in numerical_columns:
    plt.subplot(2,2,value)
    sns.boxplot(x=df[cols],hue=df['Species'])
    value+=1

plt.tight_layout()

# %% [markdown]
# ## The Iris Setosa in both PetalLengthCm and PetalWidthCm are clearly seperated to the left while Versicolor and Virginica are in the right with less gap between them,these petal features help us distingush between Setosa and others.
# ## While in the Sepal Function there is overlapping between Versicolor and Virginica, cannot distinguish between them.Setosa is also not very clearly seperated

# %% [markdown]
# ## Correlation Analysis

# %%
sns.heatmap(df.corr(numeric_only=True),annot=True)
# Out:
# <Axes: >

# %%
df.drop(columns=['Id'],inplace=True)

# %%
final_df=df[['PetalLengthCm','PetalWidthCm','SepalLengthCm']]

# %%
final_df
# Out:
#      PetalLengthCm  PetalWidthCm  SepalLengthCm
# 0              1.4           0.2            5.1
# 1              1.4           0.2            4.9
# 2              1.3           0.2            4.7
# 3              1.5           0.2            4.6
# 4              1.4           0.2            5.0
# ..             ...           ...            ...
# 145            5.2           2.3            6.7
# 146            5.0           1.9            6.3
# 147            5.2           2.0            6.5
# 148            5.4           2.3            6.2
# 149            5.1           1.8            5.9
#
# [150 rows x 3 columns]
